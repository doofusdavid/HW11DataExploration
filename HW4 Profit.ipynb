# %%
import pandas as pd
# Out:
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\site-packages\pandas\__init__.py

# %%
import pyodbc

# %%
conn = pyodbc.connect('Driver={SQL Server};'
                      'Server=BusCISSQL1601\CIS655;'
                      'Database=AdventureWorks;'
                      'Trusted_Connection=yes;')

# %%
sql = 'Select * from AdventureWorks.Production.Product'
data = pd.read_sql(sql,conn)

# %%
data.describe()
# Out:
#          ProductID  SafetyStockLevel  ReorderPoint  StandardCost    ListPrice  \
# count   505.000000        505.000000    505.000000    505.000000   505.000000
# mean    673.693069        532.138614    400.578218    257.991866   437.797604
# std     229.615420        374.635723    280.860593    460.907612   773.081484
# min       1.000000          4.000000      3.000000      0.000000     0.000000
# 25%     448.000000        100.000000     75.000000      0.000000     0.000000
# 50%     748.000000        500.000000    375.000000     23.372200    49.990000
# 75%     874.000000       1000.000000    750.000000    308.217900   564.990000
# max    1003.000000       1000.000000    750.000000   2161.294200  3578.270000
#
#             Weight  DaysToManufacture  ProductSubcategoryID  ProductModelID
# count   205.000000         505.000000            295.000000      295.000000
# mean     74.069220           1.100990             12.294915       37.444068
# ...

# %%
data['profit'] = data['ListPrice'] - data['StandardCost']

# %%
data['profitmargin'] = data['profit'] / data['ListPrice']

# %%
data = data[data['StandardCost']!=0]

# %%
data = data[data['ListPrice']!=0]

# %%
data.describe()
# Out:
#         ProductID  SafetyStockLevel  ReorderPoint  StandardCost    ListPrice  \
# count  304.000000        304.000000    304.000000    304.000000   304.000000
# mean   842.029605        284.263158    213.197368    428.572015   727.262467
# std    101.493122        219.930824    164.948118    529.161083   884.820586
# min    514.000000          4.000000      3.000000      0.856500     2.290000
# 25%    771.750000        100.000000     75.000000     37.120900    69.990000
# 50%    847.500000        500.000000    375.000000    199.613800   337.220000
# 75%    923.250000        500.000000    375.000000    601.743700  1079.990000
# max    999.000000        500.000000    375.000000   2161.294200  3578.270000
#
#             Weight  DaysToManufacture  ProductSubcategoryID  ProductModelID  \
# count   198.000000         304.000000            295.000000      295.000000
# mean     61.334293           1.769737             12.294915       37.444068
# ...

# %%
data.sort_values(by=['profit'])
# Out:
#      ProductID                             Name ProductNumber  MakeFlag  \
# 377        873              Patch Kit/8 Patches       PK-7098     False
# 216        712                     AWC Logo Cap       CA-1098     False
# 426        922                   Road Tire Tube       TT-R982     False
# 427        923                Touring Tire Tube       TT-T092     False
# 425        921               Mountain Tire Tube       TT-M928     False
# 374        870            Water Bottle - 30 oz.       WB-H098     False
# 381        877            Bike Wash - Dissolver       CL-9009     False
# 379        875                  Racing Socks, L     SO-R809-L     False
# 378        874                  Racing Socks, M     SO-R809-M     False
# 376        872                 Road Bottle Cage       BC-R205     False
# 214        710           Mountain Bike Socks, L     SO-B909-L     False
# 213        709           Mountain Bike Socks, M     SO-B909-M     False
# ...
